# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import os
import numpy as np
from tensorflow.keras.utils import to_categorical
from PIL import Image

# extract the quantum data from the .png filename and label the data pre-training
def load_quantum_state_data(image_folder_path, n_values):
    images = []
    labels = []
    skipped_files = []

    for filename in os.listdir(image_folder_path):
        if filename.endswith('.png'):
            try:
                # extract n, l, m from the filename
                n, l, m = map(int, filename.rstrip('.png').split('_'))
                
                # if n is in n_values, process the image
                if n in n_values:
                    image_file = os.path.join(image_folder_path, filename)
                    image = Image.open(image_file).convert('RGB')  # Ensure image is RGB
                    image = image.resize((128, 128))  # Resize to 128x128 pixels
                    images.append(np.array(image))
                    labels.append((n, l, m))
                else:
                    skipped_files.append(filename)
            except ValueError:
                skipped_files.append(filename)
    
    # debugging
    print(f"Loaded {len(images)} images and {len(labels)} labels.")
    print(f"Skipped {len(skipped_files)} files due to format issues or filtering: {skipped_files}")

    # extract only the principal quantum number n for labels
    n_labels = np.array([n for n, l, m in labels])
    
    return np.array(images), n_labels

# load training data for n = 1 to n = 4
training_image_folder_path = 'training-data'
n_train_values = range(1, 6)
x_train, y_train = load_quantum_state_data(training_image_folder_path, n_train_values)

# debugging
print(f"x_train shape: {x_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"Unique n values found: {np.unique(y_train)}")

# normalize images
x_train = x_train / 255.0

# set number of n classes and encode data labels
num_n_classes = np.max(y_train) + 1
y_train = tf.keras.utils.to_categorical(y_train, num_classes=num_n_classes)

# build model
base_model = tf.keras.applications.VGG16(include_top=False, input_shape=(128, 128, 3))
base_model.trainable = False  # Freeze the base model layers

model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(num_n_classes, activation="softmax")
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[tf.keras.metrics.CategoricalAccuracy()]
)

model.summary()

# begin model training
model.fit(
    x_train, y_train,
    batch_size=16,
    epochs=200,
    validation_split=0.2
)

# load test data for n = 5
test_image_folder_path = 'classification-data'
n_test_values = [3]
x_test, y_test = load_quantum_state_data(test_image_folder_path, n_test_values)

# normalize test images
x_test = x_test / 255.0

# Decode predictions to the n values
predictions = model.predict(x_test)
predicted_n = np.argmax(predictions, axis=1)

print(f"Predicted principal quantum numbers (n): {predicted_n}")

if len(predicted_n) != len(y_test):
    print(f"Warning: Mismatch in predictions. Expected {len(y_test)} predictions but got {len(predicted_n)}")
# Out:
# Loaded 35 images and 35 labels.
# Skipped 0 files due to format issues or filtering: []
# x_train shape: (35, 128, 128, 3)
# y_train shape: (35,)
# Unique n values found: [1 2 3 4 5]
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 4, 4, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 128)            │     1,048,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,764,166 (60.14 MB)
#  Trainable params: 1,049,478 (4.00 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)
# Epoch 1/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 695ms/step - categorical_accuracy: 0.3661 - loss: 2.5287 - val_categorical_accuracy: 0.0000e+00 - val_loss: 3.8823
# Epoch 2/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 589ms/step - categorical_accuracy: 0.5476 - loss: 1.2149 - val_categorical_accuracy: 0.0000e+00 - val_loss: 4.5264
# Epoch 3/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 585ms/step - categorical_accuracy: 0.5685 - loss: 1.3971 - val_categorical_accuracy: 0.0000e+00 - val_loss: 4.1852
# Epoch 4/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 605ms/step - categorical_accuracy: 0.6786 - loss: 0.9999 - val_categorical_accuracy: 0.0000e+00 - val_loss: 3.6448
# Epoch 5/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 603ms/step - categorical_accuracy: 0.6131 - loss: 0.9022 - val_categorical_accuracy: 0.0000e+00 - val_loss: 2.9130
# Epoch 6/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 603ms/step - categorical_accuracy: 0.7500 - loss: 0.7573 - val_categorical_accuracy: 0.0000e+00 - val_loss: 2.5327
# Epoch 7/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 592ms/step - categorical_accuracy: 0.6161 - loss: 0.9652 - val_categorical_accuracy: 0.0000e+00 - val_loss: 2.3971
# Epoch 8/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 611ms/step - categorical_accuracy: 0.7024 - loss: 0.8383 - val_categorical_accuracy: 0.0000e+00 - val_loss: 2.4642
# Epoch 9/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 597ms/step - categorical_accuracy: 0.7262 - loss: 0.6631 - val_categorical_accuracy: 0.0000e+00 - val_loss: 2.5538
# Epoch 10/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 651ms/step - categorical_accuracy: 0.7708 - loss: 0.5717 - val_categorical_accuracy: 0.0000e+00 - val_loss: 2
# Epoch 119/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 764ms/step - categorical_accuracy: 0.9554 - loss: 0.1242 - val_categorical_accuracy: 0.1429 - val_loss: 2.7803
# Epoch 120/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 772ms/step - categorical_accuracy: 0.9554 - loss: 0.1654 - val_categorical_accuracy: 0.1429 - val_loss: 2.6346
# Epoch 121/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 760ms/step - categorical_accuracy: 0.9762 - loss: 0.1129 - val_categorical_accuracy: 0.1429 - val_loss: 2.5737
# Epoch 122/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 771ms/step - categorical_accuracy: 1.0000 - loss: 0.0816 - val_categorical_accuracy: 0.1429 - val_loss: 2.5857
# Epoch 123/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 760ms/step - categorical_accuracy: 1.0000 - loss: 0.0766 - val_categorical_accuracy: 0.1429 - val_loss: 2.6477
# Epoch 124/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 767ms/step - categorical_accuracy: 1.0000 - loss: 0.0588 - val_categorical_accuracy: 0.1429 - val_loss: 2.6809
# Epoch 125/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 754ms/step - categorical_accuracy: 0.9762 - loss: 0.0519 - val_categorical_accuracy: 0.1429 - val_loss: 2.6947
# Epoch 126/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 780ms/step - categorical_accuracy: 0.9315 - loss: 0.1315 - val_categorical_accuracy: 0.1429 - val_loss: 2.6918
# Epoch 127/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 785ms/step - categorical_accuracy: 1.0000 - loss: 0.1057 - val_categorical_accuracy: 0.1429 - val_loss: 2.6975
# Epoch 128/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 768ms/step - categorical_accuracy: 0.9315 - loss: 0.1498 - val_categorical_accuracy: 0.1429 - val_loss: 2.5334
# Epoch 129/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 771ms/step - categorical_accuracy: 1.0000 - loss: 0.0885 - val_categorical_accuracy: 0.1429 - val_loss: 2.4446
# Epoch 130/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 745ms/step - categorical_accuracy: 0.9762 - loss: 0.0958 - val_categorical_accuracy: 0.1429 - val_loss: 2.4503
# Epoch 131/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 735ms/step - categorical_accuracy: 1.0000 - loss: 0.0483 - val_categorical_accuracy: 0.1429 - val_loss: 2.4882
# Epoch 132/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 772ms/step - categorical_accuracy: 1.0000 - loss: 0.0534 - val_categorical_accuracy: 0.1429 - val_loss: 2.4651
# Epoch 133/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 762ms/step - categorical_accuracy: 1.0000 - loss: 0.0793 - val_categorical_accuracy: 0.2857 - val_loss: 2.3536
# Epoch 134/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 780ms/step - categorical_accuracy: 0.9762 - loss: 0.1290 - val_categorical_accuracy: 0.4286 - val_loss: 2.2750
# Epoch 135/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 867ms/step - categorical_accuracy: 1.0000 - loss: 0.0837 - val_categorical_accuracy: 0.4286 - val_loss: 2.2396
# Epoch 136/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 812ms/step - categorical_accuracy: 1.0000 - loss: 0.0865 - val_categorical_accuracy: 0.4286 - val_loss: 2.2721
# Epoch 137/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 803ms/step - categorical_accuracy: 0.9524 - loss: 0.1389 - val_categorical_accuracy: 0.4286 - val_loss: 2.3165
# Epoch 138/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 749ms/step - categorical_accuracy: 1.0000 - loss: 0.0942 - val_categorical_accuracy: 0.4286 - val_loss: 2.3841
# Epoch 139/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 743ms/step - categorical_accuracy: 0.9554 - loss: 0.1205 - val_categorical_accuracy: 0.2857 - val_loss: 2.4482
# Epoch 140/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 739ms/step - categorical_accuracy: 1.0000 - loss: 0.0345 - val_categorical_accuracy: 0.1429 - val_loss: 2.5257
# Epoch 141/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 762ms/step - categorical_accuracy: 0.9762 - loss: 0.0578 - val_categorical_accuracy: 0.1429 - val_loss: 2.5574
# Epoch 142/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 801ms/step - categorical_accuracy: 1.0000 - loss: 0.0477 - val_categorical_accuracy: 0.1429 - val_loss: 2.5386
# Epoch 143/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 892ms/step - categorical_accuracy: 0.9554 - loss: 0.0825 - val_categorical_accuracy: 0.4286 - val_loss: 2.5188
# Epoch 144/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 768ms/step - categorical_accuracy: 1.0000 - loss: 0.0834 - val_categorical_accuracy: 0.4286 - val_loss: 2.5272
# Epoch 145/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 835ms/step
# Epoch 173/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 740ms/step - categorical_accuracy: 1.0000 - loss: 0.0130 - val_categorical_accuracy: 0.4286 - val_loss: 2.6206
# Epoch 174/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 730ms/step - categorical_accuracy: 1.0000 - loss: 0.0673 - val_categorical_accuracy: 0.4286 - val_loss: 2.5994
# Epoch 175/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 725ms/step - categorical_accuracy: 1.0000 - loss: 0.0411 - val_categorical_accuracy: 0.4286 - val_loss: 2.5759
# Epoch 176/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 740ms/step - categorical_accuracy: 1.0000 - loss: 0.0440 - val_categorical_accuracy: 0.4286 - val_loss: 2.5901
# Epoch 177/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 735ms/step - categorical_accuracy: 1.0000 - loss: 0.0635 - val_categorical_accuracy: 0.4286 - val_loss: 2.6491
# Epoch 178/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 728ms/step - categorical_accuracy: 1.0000 - loss: 0.0642 - val_categorical_accuracy: 0.4286 - val_loss: 2.7417
# Epoch 179/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 741ms/step - categorical_accuracy: 0.9524 - loss: 0.1467 - val_categorical_accuracy: 0.4286 - val_loss: 2.8570
# Epoch 180/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 737ms/step - categorical_accuracy: 1.0000 - loss: 0.0244 - val_categorical_accuracy: 0.4286 - val_loss: 3.0205
# Epoch 181/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 738ms/step - categorical_accuracy: 0.9554 - loss: 0.1164 - val_categorical_accuracy: 0.4286 - val_loss: 2.9934
# Epoch 182/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 736ms/step - categorical_accuracy: 1.0000 - loss: 0.0546 - val_categorical_accuracy: 0.4286 - val_loss: 2.9224
# Epoch 183/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 736ms/step - categorical_accuracy: 1.0000 - loss: 0.0714 - val_categorical_accuracy: 0.4286 - val_loss: 2.8245
# Epoch 184/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 731ms/step - categorical_accuracy: 0.9554 - loss: 0.1142 - val_categorical_accuracy: 0.4286 - val_loss: 2.7375
# Epoch 185/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 728ms/step - categorical_accuracy: 1.0000 - loss: 0.0589 - val_categorical_accuracy: 0.4286 - val_loss: 2.7214
# Epoch 186/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 737ms/step - categorical_accuracy: 0.9554 - loss: 0.0981 - val_categorical_accuracy: 0.4286 - val_loss: 2.6565
# Epoch 187/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 736ms/step - categorical_accuracy: 1.0000 - loss: 0.0468 - val_categorical_accuracy: 0.5714 - val_loss: 2.5889
# Epoch 188/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 738ms/step - categorical_accuracy: 1.0000 - loss: 0.0531 - val_categorical_accuracy: 0.4286 - val_loss: 2.5504
# Epoch 189/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 730ms/step - categorical_accuracy: 0.9762 - loss: 0.0574 - val_categorical_accuracy: 0.4286 - val_loss: 2.5455
# Epoch 190/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 742ms/step - categorical_accuracy: 0.9762 - loss: 0.0657 - val_categorical_accuracy: 0.4286 - val_loss: 2.6090
# Epoch 191/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 748ms/step - categorical_accuracy: 0.9554 - loss: 0.0906 - val_categorical_accuracy: 0.4286 - val_loss: 2.6871
# Epoch 192/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 745ms/step - categorical_accuracy: 0.9554 - loss: 0.1511 - val_categorical_accuracy: 0.4286 - val_loss: 2.7239
# Epoch 193/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 733ms/step - categorical_accuracy: 0.9554 - loss: 0.1036 - val_categorical_accuracy: 0.4286 - val_loss: 2.6622
# Epoch 194/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 736ms/step - categorical_accuracy: 1.0000 - loss: 0.0331 - val_categorical_accuracy: 0.4286 - val_loss: 2.6517
# Epoch 195/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 735ms/step - categorical_accuracy: 1.0000 - loss: 0.0705 - val_categorical_accuracy: 0.2857 - val_loss: 2.6639
# Epoch 196/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 728ms/step - categorical_accuracy: 1.0000 - loss: 0.0417 - val_categorical_accuracy: 0.2857 - val_loss: 2.6803
# Epoch 197/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 743ms/step - categorical_accuracy: 1.0000 - loss: 0.0614 - val_categorical_accuracy: 0.2857 - val_loss: 2.6981
# Epoch 198/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 734ms/step - categorical_accuracy: 0.9762 - loss: 0.0659 - val_categorical_accuracy: 0.4286 - val_loss: 2.6873
# Epoch 199/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 734ms/step - categorical_accuracy: 0.9762 - loss: 0.0446 - val_categorical_accuracy: 0.4286 - val_loss: 2.6998
# Epoch 200/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 766ms/step - categorical_accuracy: 0.9554 - loss: 0.1226 - val_categorical_accuracy: 0.2857 - val_loss: 2.7782
# Loaded 1 images and 1 labels.
# Skipped 0 files due to format issues or filtering: []
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x175387a60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Predicted principal quantum numbers (n): [4]
